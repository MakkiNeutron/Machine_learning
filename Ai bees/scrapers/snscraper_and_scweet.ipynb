# %%
from Scweet.scweet import scrape,
from Scweet.user import get_user_information, get_users_following, get_users_followers


data = scrape(words=['sundarpichai], since="2021-01-01", until="2021-09-01", from_account = None, interval=1, 
              headless=True, display_type="Top", save_images=False, 
              resume=False, filter_replies=False, proximity=False)
# Out:
# Scraping on headless mode.
# looking for tweets between 2019-04-01 and 2019-04-02 ...
#  path : https://twitter.com/search?q=(bitcoin%20OR%20ethereum)%20until%3A2019-04-02%20since%3A2019-04-01%20%20-filter%3Areplies&src=typed_query
# scroll  1
# Tweet made at: 2019-04-01T23:02:57.000Z is found.
# Tweet made at: 2019-04-01T23:54:26.000Z is found.
# Tweet made at: 2019-04-01T22:19:50.000Z is found.
# Tweet made at: 2019-04-01T22:51:33.000Z is found.
# Tweet made at: 2019-04-01T22:10:23.000Z is found.
# Tweet made at: 2019-04-01T22:55:50.000Z is found.
# Tweet made at: 2019-04-01T22:51:00.000Z is found.
# Tweet made at: 2019-04-01T23:26:44.000Z is found.
# scroll  2
# Tweet made at: 2019-04-01T23:52:20.000Z is found.
# Tweet made at: 2019-04-01T22:40:20.000Z is found.
# Tweet made at: 2019-04-01T23:00:58.000Z is found.
# Tweet made at: 2019-04-01T22:25:17.000Z is found.
# Tweet made at: 2019-04-01T23:42:59.000Z is found.
# Tweet made at: 2019-04-01T23:03:49.000Z is found.
# scroll  3
# ...

# %%
data.to_csv('C:/Users/Taimoor Baig/PycharmProjects/Web_scraping/cleaned.csv',index=False)

# %%
data
# Out:
#                                      UserScreenName          UserName  \
# 0                                        Substratum    @SubstratumNet
# 1                   ₿EG News - BitcoinExchangeGuide    @bitcoinsguide
# 2                                        Dave Jones    @Dave_Jonez_02
# 3                                             1jack         @liujackc
# 4                                     CryptoŁi_cooŁ          @li_cool
# 5                                         BULLZILLA    @CKJCryptonews
# 6                                       JRNY Crypto       @JRNYcrypto
# 7                                  DARE Tech Invest  @DareTech_Invest
# 8                                       Cypher Core      @cypher_core
# 9                               Crypto Quantamental         @CryptoQF
# 10                                           Cvatik     @cvatikphotog
# 11                                          Autonio       @AI_Autonio
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
# our search term, using syntax for Twitter's Advanced Search
search = '"Cristiano Ronaldo"'

# the scraped tweets, this is a generator
scraped_tweets = sntwitter.TwitterSearchScraper(search).get_items()

# slicing the generator to keep only the first 100 tweets
sliced_scraped_tweets = itertools.islice(scraped_tweets, 1000)

# convert to a DataFrame and keep only relevant columns
df = pd.DataFrame(sliced_scraped_tweets)#[['date', 'content','user']]#,'retweetedTweet']]

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/kompascom/status/143558497...
# 1  https://twitter.com/GENTILHOMMEPhi1/status/143...
# 2  https://twitter.com/mufcbr/status/143558478601...
# 3  https://twitter.com/CallmeObg/status/143558470...
# 4  https://twitter.com/Yada4Yadav/status/14355846...
#
#                        date  \
# 0 2021-09-08 12:45:05+00:00
# 1 2021-09-08 12:44:44+00:00
# 2 2021-09-08 12:44:19+00:00
# 3 2021-09-08 12:44:00+00:00
# 4 2021-09-08 12:43:54+00:00
#
#                                              content                   id  \
# 0  Cristiano Ronaldo punya catatan manis saat mel...  1435584977572220932
# 1  Margotton,Lizarazu,\nKylian regarde 2 butes, y...  1435584889559072774
# 2  Fábio da Silva: "Adoro Cristiano Ronaldo, porq...  1435584786014351369
# 3  @davvvymoore I love Cristiano Ronaldo and my s...  1435584704560959489
# 4  @RetroCristiano @TrendVirat @imVkohli @Cristia...  1435584683102801920
#
# ...

# %%
df.to_csv('C:/Users/Taimoor Baig/PycharmProjects/Web_scraping/Cristiano Ronaldo.csv',index=False)

# %%
loc = '34.052235, -118.243683, 10km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza geocode:"{}"'.format(loc)).get_items(), 50))[['date','username', 'content']]

# %%
df_coord
# Out:
#                                                   url  \
# 0   https://twitter.com/MeghanPsd/status/143555937...
# 1   https://twitter.com/tonepark/status/1435545684...
# 2   https://twitter.com/EvieOverride/status/143554...
# 3   https://twitter.com/RoxanaSapera/status/143554...
# 4   https://twitter.com/TokyoJournal2/status/14355...
# 5   https://twitter.com/USCOracle/status/143551802...
# 6   https://twitter.com/itspizzatimeguy/status/143...
# 7   https://twitter.com/itspizzatimeguy/status/143...
# 8   https://twitter.com/kim83rlin/status/143550438...
# 9   https://twitter.com/Midaoo762/status/143550319...
# 10  https://twitter.com/Marikeet0v0/status/1435502...
# 11  https://twitter.com/chrisshep51283/status/1435...
# 12  https://twitter.com/chrisshep51283/status/1435...
# 13  https://twitter.com/athurlow/status/1435492666...
# 14  https://twitter.com/benniearthur/status/143549...
# 15  https://twitter.com/vaineswastaken/status/1435...
# ...
