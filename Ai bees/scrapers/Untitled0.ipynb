# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install nest_asyncio

# %%
pip install twitterscraper

# %%
pip install --upgrade requests

# %%
import twint
import nest_asyncio
nest_asyncio.apply()


c = twint.Config()
c.Search = 'covid'       # topic
c.Limit = 10      # number of Tweets to scrape
#c.Store_csv = True       # store tweets in a csv file
#c.Output = "/content/drive/MyDrive/Data science/job_tests/Ai bees/dataset/taylor_swift_tweets.csv"     # path to csv file

twint.run.Search(c)

# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd

begin_date=dt.date(2020,1,1)
end_date=dt.date(2021,1,1)
limit=10
lang='english'

tweets=query_tweets("#lockdown AND #India ",begindate=begin_date,
                    enddate=end_date,limit=limit,lang=lang)
df=pd.DataFrame(t.__dict__ for t in tweets)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-cfd098da633e> in <module>()
# ----> 1 from twitterscraper import query_tweets
#       2 import datetime as dt
#       3 import pandas as pd
#       4
#       5 begin_date=dt.date(2020,1,1)
#
# ModuleNotFoundError: No module named 'twitterscraper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from twitterscraper import query_tweets
from twitterscraper.query import query_tweets_from_user
import datetime as dt 
import pandas as pd 


begin_date = dt.date(2020,7,1)
end_date = dt.date(2020,7,13)


limit = 100
lang = 'english'

#Use this to search a specific user

user = 'realDonaldTrump'
tweets = query_tweets_from_user(user)
df = pd.DataFrame(t.__dict__ for t in tweets)

df = df.loc[df['screen_name'] == user]

df = df['text']

df

# %%
#from twitterscraper import query_tweets
from twitterscraper.query import query_tweets
import datetime as dt
import pandas as pd

#Providing the range of days in which I want the data 
begin_date=dt.date(2020,4,1)
end_date=dt.date(2020,4,3)

#Providing limit to the fetched tweets and also specifying the language of the desired tweets
limit=1000
language='english'

#Extracting tweets for the Keyword “Covid-19”
tweets=query_tweets('Covid-19',limit=limit,begindate=begin_date,enddate=end_date,lang=language)

# %% [markdown]
# # In the last days, Twitter banned almost every twitter scrapers. This repository represent an alternative tool to scrap tweet

# %%
pip install Scweet

# %%
pip install snscrape

# %%
import os
import pandas as pd
from datetime import date

# %%
today = date.today()
end_date = today

# %%
search_term = 'Bhavesh Bhatt Data Scientist'
from_date = '2019-01-01'

# %%
os.system(f"snscrape --since {from_date} twitter-search '{search_term} until:{end_date}' > result-tweets.txt")
if os.stat("result-tweets.txt").st_size == 0:
  counter = 0
else:
  df = pd.read_csv('result-tweets.txt', names=['link'])
  counter = df.size

print('Number Of Tweets : '+ str(counter))

# %%
max_results = 10

# %%
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > extracted-tweets.txt"
os.system(extracted_tweets)
if os.stat("extracted-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('extracted-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)

# %%
user_name = "sundarpichai"
user_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-user '{user_name} until:{end_date}' > user-tweets.txt"
os.system(user_tweets)
if os.stat("user-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('user-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)

# %%
df.shape

# %%
df.head()

# %%
import snscrape.modules.twitter as twitteScraper

scraper = twitteScraper.TwitterUserScraper("KermitTheFrog",False)

for i, tweet in enumerate(scraper.get_item()):
  if i>2:
    break
  print(f"{i}content:{tweet.content}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9bd8f064c6dd> in <module>()
#       1 import snscrape.modules.twitter as twitteScraper
#       2
# ----> 3 scraper = twitteScraper.TwitterUserScraper("KermitTheFrog",False)
#       4
#       5 for i, tweet in enumerate(scraper.get_item()):
#
# TypeError: __init__() takes 2 positional arguments but 3 were given
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 343.0 secs

# %%
import twint
import nest_asyncio
nest_asyncio.apply()
# Configure
c = twint.Config()
c.Username = "realDonaldTrump"
c.Search = "great"

# Run
twint.run.Search(c)

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
# our search term, using syntax for Twitter's Advanced Search
search = '"data science"'

# the scraped tweets, this is a generator
scraped_tweets = sntwitter.TwitterSearchScraper(search+'filter:replies').get_items()

# slicing the generator to keep only the first 100 tweets
sliced_scraped_tweets = itertools.islice(scraped_tweets, 100)

# convert to a DataFrame and keep only relevant columns
df = pd.DataFrame(sliced_scraped_tweets)#[['date', 'content','user']]#,'retweetedTweet']]

# %%
df.head()
# Out:
#                                                  url  ... tcooutlinksss
# 0  https://twitter.com/ArturoRConstan1/status/143...  ...
# 1  https://twitter.com/nwilliams030/status/143538...  ...
# 2  https://twitter.com/rhinOrtiz/status/143538915...  ...
# 3  https://twitter.com/SarahJoSinnott/status/1435...  ...
# 4  https://twitter.com/AndrewJulioDEV/status/1435...  ...
#
# [5 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['url', 'date', 'content', 'id', 'username', 'outlinks', 'outlinksss',
#        'tcooutlinks', 'tcooutlinksss'],
#       dtype='object')

# %%
loc = '34.052235, -118.243683, 10km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza geocode:"{}"'.format(loc)).get_items(), 50))[['date', 'content']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6ebdbdcb7dc6> in <module>()
#       1 loc = '34.052235, -118.243683, 10km'
# ----> 2 df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
#       3     'pizza geocode:"{}"'.format(loc)).get_items(), 50))[['date', 'content']]
#
# NameError: name 'pd' is not defined
